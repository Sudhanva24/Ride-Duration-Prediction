# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/sudhanvasavyasachi/Desktop/Projects/Hackathon micron/Data/micron_half.csv")
# Out:
# /var/folders/7w/qs77cz_11630n9gydm61vjpc0000gn/T/ipykernel_38750/3250301900.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/Users/sudhanvasavyasachi/Desktop/Projects/Hackathon micron/Data/micron_half.csv")

# %%
df.head()
# Out:
#    VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0       1.0  01/01/2020 12:28:15 AM  01/01/2020 12:33:03 AM              1.0
# 1       1.0  01/01/2020 12:35:39 AM  01/01/2020 12:43:04 AM              1.0
# 2       1.0  01/01/2020 12:47:41 AM  01/01/2020 12:53:52 AM              1.0
# 3       1.0  01/01/2020 12:55:23 AM  01/01/2020 01:00:14 AM              1.0
# 4       2.0  01/01/2020 12:01:58 AM  01/01/2020 12:04:16 AM              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
# ...

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12324249 entries, 0 to 12324248
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           float64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: datetime64[ns](1), float64(13), int64(2), object(2)
# memory usage: 1.7+ GB

# %%
df.isna().sum()
# Out:
# VendorID                 92360
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          92360
# trip_distance                0
# RatecodeID               92360
# store_and_fwd_flag       92360
# PULocationID                 0
# DOLocationID                 0
# payment_type             92360
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12949

# %%
df = df.drop_duplicates(keep='first')

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Sample 1M rows randomly
df_sampled = df.sample(n=1000000, random_state=42)

# %%
df_sampled
# Out:
#           VendorID tpep_pickup_datetime   tpep_dropoff_datetime  \
# 2379926        1.0  2020-01-13 13:35:25  01/13/2020 01:54:29 PM
# 1261478        2.0  2020-01-08 08:00:12  01/08/2020 08:12:32 AM
# 417258         2.0  2020-01-03 15:25:34  01/03/2020 03:34:16 PM
# 764028         2.0  2020-01-05 13:49:54  01/05/2020 01:58:08 PM
# 8296930        2.0  2020-02-09 16:16:04  02/09/2020 04:44:58 PM
# ...            ...                  ...                     ...
# 3367959        2.0  2020-01-17 19:04:40  01/17/2020 07:28:00 PM
# 11248087       1.0  2020-02-23 17:52:12  02/23/2020 06:01:27 PM
# 5695364        1.0  2020-01-29 09:48:06  01/29/2020 09:53:51 AM
# 10334426       1.0  2020-02-19 15:12:21  02/19/2020 03:17:34 PM
# 3502356        1.0  2020-01-18 13:16:24  01/18/2020 01:22:18 PM
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 2379926               1.0           2.70         1.0                  N
# ...

# %%
df_sampled.to_csv("sampled_data.csv",index=False)
